# %%
from zooscript import generate_random_walk, plot_path

# %%
grid_size = 100
num_steps = 1000
path = generate_random_walk(grid_size, num_steps)

# %%
plot_path(path, grid_size)
